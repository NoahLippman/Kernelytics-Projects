# %%
import pandas as pd
from scipy.stats import rankdata

# Load your file (replace with your actual filename if different)
df = pd.read_csv('KCL_stuff+.csv')

# Drop rows with missing stuff+ or TaggedPitchType or Pitcher
df = df.dropna(subset=['stuff+', 'TaggedPitchType', 'Pitcher'])

# Group by Pitcher and TaggedPitchType, calculate average stuff+
grouped = df.groupby(['Pitcher', 'TaggedPitchType'])['stuff+'].mean().reset_index()

# For each TaggedPitchType, calculate percentile for each player
def add_percentile(sub_df):
    sub_df['stuff+_percentile'] = rankdata(sub_df['stuff+'], method='average') / len(sub_df) * 100
    return sub_df

result = grouped.groupby('TaggedPitchType', group_keys=False).apply(add_percentile).reset_index(drop=True)
result = result.sort_values(['TaggedPitchType', 'stuff+'], ascending=[True, False])

# Save to CSV
result.to_csv('player_stuffplus_percentiles.csv', index=False)

# Also: Group by Pitcher, calculate average stuff+ across all pitch types and sort
pitcher_avg = df.groupby('Pitcher')['stuff+'].mean().reset_index()
pitcher_avg = pitcher_avg.sort_values('stuff+', ascending=False)
pitcher_avg.to_csv('pitcher_average_stuffplus.csv', index=False)

# Display both results
print("Pitcher + Pitch Type Percentiles:")
display(result)
print("Pitcher Average Stuff+ (All Types):")
display(pitcher_avg)
# Out:
# Pitcher + Pitch Type Percentiles:
# C:\Users\isu_mvquirk_admin\AppData\Local\Temp\ipykernel_22116\1640809547.py:18: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result = grouped.groupby('TaggedPitchType', group_keys=False).apply(add_percentile).reset_index(drop=True)
#               Pitcher TaggedPitchType      stuff+  stuff+_percentile
# 10    Braden Deverman        Changeup  404.008341         100.000000
# 93        Lucas Frank        Changeup  402.123660          95.833333
# 30         Caleb Ochs        Changeup  393.497120          91.666667
# 113     Miles Woolsey        Changeup  384.886598          87.500000
# 123      Nolan Bowles        Changeup  332.808016          83.333333
# ..                ...             ...         ...                ...
# 139      Payton Knoll          Slider   27.024548          12.820513
# 115     Miles Woolsey          Slider   17.120329          10.256410
# 9    Braden Alexander          Slider   14.101174           7.692308
# 106   Marshall Ingold          Slider    6.945494           5.128205
# 37    Cameron Clifton          Slider    6.916741           2.564103
#
# [157 rows x 4 columns]
# Pitcher Average Stuff+ (All Types):
#                Pitcher      stuff+
# 44       Owen Shissler  374.970426
# 30       Logan Elsbury  265.713257
# 25        Joey Kahwaji  217.049704
# 49      Sammy Driscoll  169.120928
# 48         Roy Rolston  168.128120
# 53      Tyson Sorensen  165.713950
# 24        Joe Stellano  159.600963
# 37        Matt Brummer  157.473855
# 9          Caden Addis  155.998325
# 16       Cooper Stolfa  155.234267
# 27            Kam Ross  154.249784
# 33         Luke Gallet  153.131468
# 36         Mason Orton  152.780967
# 31         Logan Lynch  138.465730
# 46        Payton Knoll  129.004187
# 8        Cade Starrick  128.894336
# 1           Andrew Tay  117.762364
# 6        Brett Granger  117.727715
# 21          Jack Piper  114.904338
# 13         Cayden Rose  108.583138
# 7    Brody Stonecipher  106.641014
# 17        Devan Tupper  104.703679
# 42      Nolan Vanduzer  103.964595
# 23      Jackson Beiler   98.703519
# 20       Ethan Robbins   98.425997
# 38       Miles Woolsey   97.124274
# 28  Kellen Hershberger   96.514602
# 34      Madden Johnson   95.578993
# 26           Kam  Ross   94.759683
# 3      Braden Deverman   91.276797
# 19          Ethan Plym   87.030539
# 2     Braden Alexander   83.145697
# 40        Noah Suttles   73.698349
# 39     Mitchell Wilson   72.732953
# 29      Lawson Shickel   72.623580
# 5         Brandon Ward   71.023990
# 32         Lucas Frank   70.038824
# 10          Caleb Ochs   69.483386
# 4          Braden Mehn   69.087658
# 41        Nolan Bowles   69.039478
# 15         Connor Hale   68.682097
# 12      Canden Hardman   67.740188
# 45     Patrick Kennedy   67.050346
# 22         Jack Wisdom   64.982707
# 47        Reed Frazier   59.444629
# 0          Adan Nieves   54.482315
# 52      Thomas Mickels   53.236176
# 35     Marshall Ingold   51.322665
# 18        Donte Frantz   45.401190
# 51    Teagan Disharoon   42.000192
# 43          Owen Laroe   41.768053
# 14       Cole Mcclusky   40.647959
# 11     Cameron Clifton   31.507815
# 50    Teagan Disharoom   25.862192
